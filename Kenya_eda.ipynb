# %% [markdown]
# <a href="https://colab.research.google.com/github/meti-creator/climate-challenge-week0/blob/eda-kenya/Kenya_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/kenya (1).csv')
df
# Out:
#       YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0     2015    1  19.56    28.99    12.09      16.90         0.00  45.32  3.12
# 1     2015    2  19.63    29.77    11.04      18.73         0.00  38.76  3.23
# 2     2015    3  20.40    30.57    11.71      18.86         0.00  41.75  3.46
# 3     2015    4  21.33    31.20    13.02      18.18         3.49  51.87  2.29
# 4     2015    5  20.41    29.52    12.38      17.14         1.79  48.04  1.77
# ...    ...  ...    ...      ...      ...        ...          ...    ...   ...
# 4103  2026   86  19.37    25.40    15.39      10.01         2.67  81.97  2.47
# 4104  2026   87  19.66    26.40    15.24      11.16         0.59  77.40  1.98
# 4105  2026   88  19.72    26.54    14.41      12.13         0.82  77.71  1.77
# 4106  2026   89  19.68    26.81    13.86      12.95         4.59  79.29  2.01
# 4107  2026   90  19.59    25.54    15.37      10.17         1.29  80.88  2.15
#
#       WS2M_MAX     PS   QV2M
# ...

# %%
#add country column
df['country']='Kenya'
df
# Out:
#       YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0     2015    1  19.56    28.99    12.09      16.90         0.00  45.32  3.12
# 1     2015    2  19.63    29.77    11.04      18.73         0.00  38.76  3.23
# 2     2015    3  20.40    30.57    11.71      18.86         0.00  41.75  3.46
# 3     2015    4  21.33    31.20    13.02      18.18         3.49  51.87  2.29
# 4     2015    5  20.41    29.52    12.38      17.14         1.79  48.04  1.77
# ...    ...  ...    ...      ...      ...        ...          ...    ...   ...
# 4103  2026   86  19.37    25.40    15.39      10.01         2.67  81.97  2.47
# 4104  2026   87  19.66    26.40    15.24      11.16         0.59  77.40  1.98
# 4105  2026   88  19.72    26.54    14.41      12.13         0.82  77.71  1.77
# 4106  2026   89  19.68    26.81    13.86      12.95         4.59  79.29  2.01
# 4107  2026   90  19.59    25.54    15.37      10.17         1.29  80.88  2.15
#
# ...

# %%
df['Date'] = pd.to_datetime(df['YEAR'] * 1000 + df['DOY'], format='%Y%j')
df.head()
# Out:
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    1  19.56    28.99    12.09      16.90         0.00  45.32  3.12
# 1  2015    2  19.63    29.77    11.04      18.73         0.00  38.76  3.23
# 2  2015    3  20.40    30.57    11.71      18.86         0.00  41.75  3.46
# 3  2015    4  21.33    31.20    13.02      18.18         3.49  51.87  2.29
# 4  2015    5  20.41    29.52    12.38      17.14         1.79  48.04  1.77
#
#    WS2M_MAX     PS  QV2M country       Date
# 0      4.76  83.68  6.88   Kenya 2015-01-01
# 1      4.35  83.67  5.85   Kenya 2015-01-02
# 2      4.68  83.69  6.65   Kenya 2015-01-03
# 3      4.00  83.62  8.60   Kenya 2015-01-04
# 4      4.05  83.54  7.64   Kenya 2015-01-05

# %%
df['Month'] = df['Date'].dt.month
df.head()
# Out:
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    1  19.56    28.99    12.09      16.90         0.00  45.32  3.12
# 1  2015    2  19.63    29.77    11.04      18.73         0.00  38.76  3.23
# 2  2015    3  20.40    30.57    11.71      18.86         0.00  41.75  3.46
# 3  2015    4  21.33    31.20    13.02      18.18         3.49  51.87  2.29
# 4  2015    5  20.41    29.52    12.38      17.14         1.79  48.04  1.77
#
#    WS2M_MAX     PS  QV2M country       Date  Month
# 0      4.76  83.68  6.88   Kenya 2015-01-01      1
# 1      4.35  83.67  5.85   Kenya 2015-01-02      1
# 2      4.68  83.69  6.65   Kenya 2015-01-03      1
# 3      4.00  83.62  8.60   Kenya 2015-01-04      1
# 4      4.05  83.54  7.64   Kenya 2015-01-05      1

# %%
import numpy as np
df = df.replace(-999, np.nan)
df.head()
# Out:
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    1  19.56    28.99    12.09      16.90         0.00  45.32  3.12
# 1  2015    2  19.63    29.77    11.04      18.73         0.00  38.76  3.23
# 2  2015    3  20.40    30.57    11.71      18.86         0.00  41.75  3.46
# 3  2015    4  21.33    31.20    13.02      18.18         3.49  51.87  2.29
# 4  2015    5  20.41    29.52    12.38      17.14         1.79  48.04  1.77
#
#    WS2M_MAX     PS  QV2M country       Date  Month
# 0      4.76  83.68  6.88   Kenya 2015-01-01      1
# 1      4.35  83.67  5.85   Kenya 2015-01-02      1
# 2      4.68  83.69  6.65   Kenya 2015-01-03      1
# 3      4.00  83.62  8.60   Kenya 2015-01-04      1
# 4      4.05  83.54  7.64   Kenya 2015-01-05      1

# %%
num_duplicates = df.duplicated().sum()
print(f"Number of duplicate rows found: {num_duplicates}")

if num_duplicates > 0:
    df.drop_duplicates(inplace=True)
    print("Duplicate rows have been removed.")
else:
    print("No duplicate rows found.")

# By default, df.duplicated() considers all columns to identify duplicates.
# If you wanted to check for duplicates based on specific columns, you would pass a subset argument, e.g., df.duplicated(subset=['YEAR', 'DOY']).
print("Duplicate check was performed across all columns by default.")
df.head()
# Out:
# Number of duplicate rows found: 0
# No duplicate rows found.
# Duplicate check was performed across all columns by default.
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    1  19.56    28.99    12.09      16.90         0.00  45.32  3.12
# 1  2015    2  19.63    29.77    11.04      18.73         0.00  38.76  3.23
# 2  2015    3  20.40    30.57    11.71      18.86         0.00  41.75  3.46
# 3  2015    4  21.33    31.20    13.02      18.18         3.49  51.87  2.29
# 4  2015    5  20.41    29.52    12.38      17.14         1.79  48.04  1.77
#
#    WS2M_MAX     PS  QV2M country       Date  Month
# 0      4.76  83.68  6.88   Kenya 2015-01-01      1
# 1      4.35  83.67  5.85   Kenya 2015-01-02      1
# 2      4.68  83.69  6.65   Kenya 2015-01-03      1
# 3      4.00  83.62  8.60   Kenya 2015-01-04      1
# 4      4.05  83.54  7.64   Kenya 2015-01-05      1

# %%
numeric_df = df.select_dtypes(include=['number'])
display(numeric_df.describe())
# Out:
#               YEAR          DOY          T2M      T2M_MAX      T2M_MIN  \
# count  4108.000000  4108.000000  4108.000000  4108.000000  4108.000000
# mean   2020.131451   180.121227    20.427600    27.838717    14.673169
# std       3.248907   106.294767     1.440824     2.358770     1.415691
# min    2015.000000     1.000000    15.260000    18.880000     8.970000
# 25%    2017.000000    86.000000    19.460000    26.297500    13.700000
# 50%    2020.000000   179.000000    20.360000    27.875000    14.750000
# 75%    2023.000000   272.000000    21.400000    29.520000    15.750000
# max    2026.000000   366.000000    25.400000    34.270000    18.750000
#
#          T2M_RANGE  PRECTOTCORR         RH2M         WS2M     WS2M_MAX  \
# count  4108.000000  4108.000000  4108.000000  4108.000000  4108.000000
# mean     13.165548     1.468162    65.845355     3.061765     4.375241
# std       2.605174     3.180228     9.934196     0.853218     0.992156
# ...

# %%
numeric_df = df.select_dtypes(include=['number'])
display(numeric_df.describe())
# Out:
#               YEAR          DOY          T2M      T2M_MAX      T2M_MIN  \
# count  4108.000000  4108.000000  4108.000000  4108.000000  4108.000000
# mean   2020.131451   180.121227    20.427600    27.838717    14.673169
# std       3.248907   106.294767     1.440824     2.358770     1.415691
# min    2015.000000     1.000000    15.260000    18.880000     8.970000
# 25%    2017.000000    86.000000    19.460000    26.297500    13.700000
# 50%    2020.000000   179.000000    20.360000    27.875000    14.750000
# 75%    2023.000000   272.000000    21.400000    29.520000    15.750000
# max    2026.000000   366.000000    25.400000    34.270000    18.750000
#
#          T2M_RANGE  PRECTOTCORR         RH2M         WS2M     WS2M_MAX  \
# count  4108.000000  4108.000000  4108.000000  4108.000000  4108.000000
# mean     13.165548     1.468162    65.845355     3.061765     4.375241
# std       2.605174     3.180228     9.934196     0.853218     0.992156
# ...

# %%
numeric_df = df.select_dtypes(include=['number'])
print(numeric_df.describe())
# Out:
#               YEAR          DOY          T2M      T2M_MAX      T2M_MIN  \
# count  4108.000000  4108.000000  4108.000000  4108.000000  4108.000000
# mean   2020.131451   180.121227    20.427600    27.838717    14.673169
# std       3.248907   106.294767     1.440824     2.358770     1.415691
# min    2015.000000     1.000000    15.260000    18.880000     8.970000
# 25%    2017.000000    86.000000    19.460000    26.297500    13.700000
# 50%    2020.000000   179.000000    20.360000    27.875000    14.750000
# 75%    2023.000000   272.000000    21.400000    29.520000    15.750000
# max    2026.000000   366.000000    25.400000    34.270000    18.750000
#
#          T2M_RANGE  PRECTOTCORR         RH2M         WS2M     WS2M_MAX  \
# count  4108.000000  4108.000000  4108.000000  4108.000000  4108.000000
# mean     13.165548     1.468162    65.845355     3.061765     4.375241
# std       2.605174     3.180228     9.934196     0.853218     0.992156
# ...

# %% [markdown]
# key observation
#
# Data Completeness: All 4108 entries in the numeric columns are non-null, indicating a complete dataset for these features after initial processing.
#
# Temperature Profile: The data shows a consistently warm climate in Sudan, with an average daily temperature (T2M) of approximately 26.84°C. There are significant diurnal temperature variations, with an average daily range (T2M_RANGE) of about 13.85°C. Extreme maximum temperatures can reach up to 42.64°C.
#
# Precipitation Variability: Precipitation (PRECTOTCORR) is characterized by a low average (3.74 mm) but extremely high variability. The vast majority of days likely experience minimal to no rainfall (median 0.11 mm, 25th percentile 0.00 mm), while occasional heavy rainfall events are evident, reaching up to 122.65 mm on certain days.
# Humidity & Wind: Relative humidity (RH2M) averages around 48.87%, showing moderate and variable levels. Wind speeds (WS2M) are generally moderate, averaging 3.41 m/s.
#
#  Atmospheric Pressure: Surface pressure (PS) is very stable, averaging 96.35 hPa with minimal fluctuation, which is typical for a consistent atmospheric environment.
# I will also modify the cell to ensure the descriptive statistics are explicitly printed for future reference.
#
# Here are the key observations from the descriptive statistics of the numerical data:
#
# Data Coverage: All numeric columns shown (YEAR, DOY, T2M, T2M_MAX, T2M_MIN, T2M_RANGE, PRECTOTCORR, RH2M, WS2M, WS2M_MAX, PS, QV2M, Month) have 4108 non-null entries, indicating a complete dataset for these variables.
#
# Temperature (T2M, T2M_MAX, T2M_MIN, T2M_RANGE):
# The average daily temperature (T2M) is approximately 28.76°C, with a minimum of 13.18°C and a maximum of 37.99°C.
# The average daily maximum temperature (T2M_MAX) is around 36.77°C, while the average daily minimum (T2M_MIN) is about 21.51°C.
# The T2M_RANGE (difference between max and min daily temperature) averages around 15.27°C, suggesting notable diurnal temperature variations.
#
# Precipitation (PRECTOTCORR):
# The average daily precipitation is very low at 0.64 mm. However, the standard deviation is 3.06 mm and the maximum is 66.49 mm. This indicates that while most days have little to no precipitation (median is 0 mm, 75th percentile is 0.01 mm), there are occasional, very heavy rainfall events.
#
# Relative Humidity (RH2M):
# Average relative humidity is around 31.36%, with a high standard deviation of 17.85, suggesting considerable variability in humidity levels.
#
# Wind Speed (WS2M, WS2M_MAX):
# The average daily wind speed (WS2M) is about 3.48 m/s, and the maximum daily wind speed (WS2M_MAX) averages 5.16 m/s. Wind speeds appear moderate overall.
#
# Surface Pressure (PS):
# Surface pressure averages around 96.35 hPa with a very low standard deviation of 0.27, indicating high stability.
#
# Specific Humidity (QV2M):
# Average specific humidity is 7.86 g/kg, reflecting the amount of water vapor in the air, with a standard deviation of 4.88, suggesting variability.
# Month: The Month column ranges from 1 to 12, as expected

# %%
missing_values = df.isna().sum()
missing_percentage = (missing_values / len(df)) * 100

# Create a DataFrame for missing info
missing_info = pd.DataFrame({
    'Missing Values': missing_values,
    'Percentage (%)': missing_percentage
})

# Filter for columns with >5% missing values
high_missing = missing_info[missing_info['Percentage (%)'] > 5]

if not high_missing.empty:
    print("Columns with more than 5% missing values:")
    display(high_missing.sort_values(by='Percentage (%)', ascending=False))
    print("Note: High missing values in these columns could indicate data collection issues, sensor failures, or regional data gaps, potentially biasing analysis if not handled (e.g., via imputation or exclusion).")
else:
    print("No columns have more than 5% missing values.")
# Out:
# No columns have more than 5% missing values.

# %% [markdown]
# ### Interpretation of Missing Values
#
# **Analysis of columns with >5% nulls:**
#
# *   **[List specific columns here if any appear with >5% nulls after execution]** For example, if 'Column_X' has 10% missing values:
#     *   **Implication**: A high percentage of missing values in a column like 'Column_X' can significantly impact our analysis. Depending on the nature of the data and the analysis goals, several strategies might be considered:
#         *   **Imputation**: Fill missing values using techniques like mean, median, mode imputation, or more advanced methods like K-Nearest Neighbors (KNN) or regression imputation. This should be done carefully to avoid introducing bias.
#         *   **Deletion**: If the percentage of missing values is very high (e.g., >70-80%) and the column is not critical, or if the number of rows with missing values is small compared to the total dataset, rows or columns with missing data might be dropped. However, this can lead to loss of valuable information or biased results.
#         *   **Advanced Modeling**: Some machine learning models can handle missing values inherently.
#
# It's important to investigate the cause of missingness (e.g., Missing Completely at Random (MCAR), Missing at Random (MAR), Missing Not at Random (MNAR)) to choose the most appropriate handling strategy.

# %%
from scipy.stats import zscore

z_score_cols = ['T2M', 'T2M_MAX', 'T2M_MIN', 'PRECTOTCORR', 'RH2M', 'WS2M', 'WS2M_MAX']

for col in z_score_cols:
    df[f'{col}_Zscore'] = zscore(df[col], nan_policy='omit')

# Identify outliers where |Z| > 3
outlier_mask = pd.DataFrame()
for col in z_score_cols:
    outlier_mask = pd.concat([outlier_mask, (df[f'{col}_Zscore'].abs() > 3)], axis=1)

df['is_outlier'] = outlier_mask.any(axis=1)

outlier_count = df['is_outlier'].sum()
print(f"Number of rows with at least one outlier (Z-score > 3): {outlier_count}")

display(df[df['is_outlier']].head())
# Out:
# Number of rows with at least one outlier (Z-score > 3): 121
#     YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 14  2015   15  21.24    31.17    12.59      18.58         0.00  28.42  3.27
# 15  2015   16  22.95    32.70    14.62      18.08         0.00  29.64  2.30
# 16  2015   17  23.00    32.29    15.79      16.50         0.00  29.43  2.71
# 17  2015   18  23.38    32.42    13.97      18.45         0.16  32.67  1.43
# 45  2015   46  22.14    27.92    18.11       9.81        23.09  61.69  0.97
#
#     WS2M_MAX  ...       Date  Month T2M_Zscore T2M_MAX_Zscore  T2M_MIN_Zscore  \
# 14      4.78  ... 2015-01-15      1   0.563913       1.412469       -1.471665
# 15      3.41  ... 2015-01-16      1   1.750878       2.061191       -0.037562
# 16      3.91  ... 2015-01-17      1   1.785585       1.887350        0.788990
# 17      3.07  ... 2015-01-18      1   2.049355       1.942470       -0.496757
# ...

# %% [markdown]
# ## Outlier Treatment Strategy
# **Decision:** Retain all identified outliers.
#
# **Reasoning:**
# *   **Scientific Relevance:** In climate datasets, outliers often represent genuine extreme weather events (e.g., peak temperatures or heavy precipitation). Removing them would result in a loss of critical information regarding climate volatility.
# *   **Data Integrity:** There is no evidence to suggest these points are the result of sensor errors or manual data entry mistakes.
# *   **Modeling Impact:** Retaining these points ensures the model accounts for "tail risks" and accurately reflects the real-world variance of the climate data.

# %%
# The decision is to retain all outliers, so no explicit code for removal or capping is needed here.
# The 'is_outlier' column has already been added to the DataFrame to mark them.
# Display a sample of the DataFrame including the 'is_outlier' column to confirm.
display(df.head())
# Out:
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    1  19.56    28.99    12.09      16.90         0.00  45.32  3.12
# 1  2015    2  19.63    29.77    11.04      18.73         0.00  38.76  3.23
# 2  2015    3  20.40    30.57    11.71      18.86         0.00  41.75  3.46
# 3  2015    4  21.33    31.20    13.02      18.18         3.49  51.87  2.29
# 4  2015    5  20.41    29.52    12.38      17.14         1.79  48.04  1.77
#
#    WS2M_MAX  ...       Date  Month T2M_Zscore T2M_MAX_Zscore  T2M_MIN_Zscore  \
# 0      4.76  ... 2015-01-01      1  -0.602229       0.488146       -1.824893
# 1      4.35  ... 2015-01-02      1  -0.553639       0.818867       -2.566670
# 2      4.68  ... 2015-01-03      1  -0.019158       1.158068       -2.093345
# 3      4.00  ... 2015-01-04      1   0.626385       1.425189       -1.167890
# 4      4.05  ... 2015-01-05      1  -0.012217       0.712866       -1.620021
#
# ...

# %%
# 1. Drop rows with missing values in more than 30% of the columns
limit = int(len(df.columns) * 0.7)
df = df.dropna(thresh=limit)

# 2. Apply forward-fill to the remaining missing weather variables
df = df.ffill()
df.head()
# Out:
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    1  19.56    28.99    12.09      16.90         0.00  45.32  3.12
# 1  2015    2  19.63    29.77    11.04      18.73         0.00  38.76  3.23
# 2  2015    3  20.40    30.57    11.71      18.86         0.00  41.75  3.46
# 3  2015    4  21.33    31.20    13.02      18.18         3.49  51.87  2.29
# 4  2015    5  20.41    29.52    12.38      17.14         1.79  48.04  1.77
#
#    WS2M_MAX  ...       Date  Month T2M_Zscore T2M_MAX_Zscore  T2M_MIN_Zscore  \
# 0      4.76  ... 2015-01-01      1  -0.602229       0.488146       -1.824893
# 1      4.35  ... 2015-01-02      1  -0.553639       0.818867       -2.566670
# 2      4.68  ... 2015-01-03      1  -0.019158       1.158068       -2.093345
# 3      4.00  ... 2015-01-04      1   0.626385       1.425189       -1.167890
# 4      4.05  ... 2015-01-05      1  -0.012217       0.712866       -1.620021
#
# ...

# %% [markdown]
# ## Handling Missing Values
# **Strategy:** Hybrid approach using row-wise deletion and Forward-Fill (ffill).
#
# **1. Row Deletion (30% Threshold):**
# Rows missing more than 30% of their features were removed. When a significant portion of
# a record is missing, imputation becomes unreliable and may introduce synthetic noise
# rather than capturing actual environmental trends.
#
# **2. Forward-Fill (ffill) for Weather Variables:**
# For the remaining missing values, I applied a forward-fill strategy.
# * **Reasoning:** Climate data is chronological and highly autocorrelated. Weather
# conditions at time $t$ are typically the most accurate predictors for time $t+1$.
# Forward-filling preserves this temporal continuity without shifting the mean
# as drastically as mean-imputation might.

# %%
df.to_csv('Sudan_clean.csv', index=False)
print('DataFrame successfully exported to Sudan_clean.csv')
# Out:
# DataFrame successfully exported to Sudan_clean.csv

# %% [markdown]
# # Time series Analysis

# %%
import matplotlib.pyplot as plt


# Create a datetime index
if 'YEAR' in df.columns and 'MO' in df.columns:
    df['Date'] = pd.to_datetime(df[['YEAR', 'MO']].assign(DAY=1))
else:
    # Adjust this if your date column has a different name
    df['Date'] = pd.to_datetime(df['Date'])

df.set_index('Date', inplace=True)

# 2. Resample to Monthly Average
monthly_t2m = df['T2M'].resample('M').mean()

# 3. Identify Warmest and Coolest Months
warmest_month = monthly_t2m.idxmax()
warmest_val = monthly_t2m.max()

coolest_month = monthly_t2m.idxmin()
coolest_val = monthly_t2m.min()

# 4. Plotting
plt.figure(figsize=(14, 6))
plt.plot(monthly_t2m.index, monthly_t2m.values, color='teal', linewidth=2, label='Monthly Avg T2M')

# Annotate Warmest
plt.annotate(f'Warmest: {warmest_val:.1f}°C\n({warmest_month.strftime("%b %Y")})',
             xy=(warmest_month, warmest_val),
             xytext=(warmest_month, warmest_val + 1),
             arrowprops=dict(facecolor='red', shrink=0.05, width=1, headwidth=8),
             horizontalalignment='center', color='red', fontweight='bold')

# Annotate Coolest
plt.annotate(f'Coolest: {coolest_val:.1f}°C\n({coolest_month.strftime("%b %Y")})',
             xy=(coolest_month, coolest_val),
             xytext=(coolest_month, coolest_val - 2),
             arrowprops=dict(facecolor='blue', shrink=0.05, width=1, headwidth=8),
             horizontalalignment='center', color='blue', fontweight='bold')

plt.title('Monthly Average Temperature (T2M) in Ethiopia (2015–2026)', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Temperature (°C)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.tight_layout()

plt.savefig('monthly_t2m_plot.png')
plt.show()
# Out:
# /tmp/ipykernel_8951/3019109510.py:14: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_t2m = df['T2M'].resample('M').mean()

# %%
monthly_prectotcorr = df['PRECTOTCORR'].resample('M').sum()

# Identify peak rainy season months (top 2 months for example)
peak_months = monthly_prectotcorr.nlargest(2)

plt.figure(figsize=(14, 7))
monthly_prectotcorr.plot(kind='bar', color='skyblue')

plt.title('Monthly Total Precipitation (PRECTOTCORR) in Kenya (2015–2026)', fontsize=14)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Total Precipitation (mm)', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(rotation=45)
plt.tight_layout()

# Annotate peak months
for date, value in peak_months.items():
    plt.annotate(f'{value:.1f} mm', xy=(date, value),
                 xytext=(date, value + monthly_prectotcorr.max() * 0.05),
                 arrowprops=dict(facecolor='red', shrink=0.05, width=1, headwidth=8),
                 horizontalalignment='center', color='red', fontweight='bold')

plt.savefig('monthly_prectotcorr_bar_chart.png')
plt.show()
# Out:
# /tmp/ipykernel_8951/2072325245.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_prectotcorr = df['PRECTOTCORR'].resample('M').sum()

# %% [markdown]
# ### Observations on Monthly Precipitation
#
# Based on the monthly total precipitation bar chart for Kenya (2015–2026):
#
# *   **Rainy Seasons:** The plot clearly indicates a bimodal rainfall pattern, which is typical for equatorial regions like Kenya. There appear to be two distinct rainy seasons.
# *   **Peak Months:** The annotations highlight the months with the highest total precipitation, which correspond to the peak of these rainy seasons.
# *   **Dry Seasons:** Conversely, there are noticeable dry periods with significantly lower precipitation totals, particularly during certain months.
# *   **Inter-annual Variability:** While this chart aggregates across years, if we were to look at individual years, we might observe variability in the timing and intensity of these rainy seasons year-to-year.

# %% [markdown]
# # Correlation & Relationship Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Heatmap of correlations across all numeric columns
numeric_cols = df.select_dtypes(include=['number'])
correlation_matrix = numeric_cols.corr()

plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Numeric Columns')
plt.show()

# 2. Scatter plots
# T2M vs. RH2M
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='T2M', y='RH2M')
plt.title('Scatter Plot: T2M vs. RH2M')
plt.xlabel('Temperature at 2 Meters (T2M)')
plt.ylabel('Relative Humidity at 2 Meters (RH2M)')
plt.show()

# T2M_RANGE vs. WS2M
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='T2M_RANGE', y='WS2M')
plt.title('Scatter Plot: T2M_RANGE vs. WS2M')
plt.xlabel('Temperature Range at 2 Meters (T2M_RANGE)')
plt.ylabel('Wind Speed at 2 Meters (WS2M)')
plt.show()

strong_correlations = correlation_matrix.unstack()
strong_correlations = strong_correlations[strong_correlations != 1.0] # Remove self-correlations
strong_correlations = strong_correlations.abs().sort_values(ascending=False) # Sort by absolute value

unique_strong_correlations = {}
for (col1, col2), value in strong_correlations.items():
    if col1 == col2: # Skip self-correlations (already handled by != 1.0, but good to be explicit)
        continue
    sorted_pair = tuple(sorted((col1, col2)))
    if sorted_pair not in unique_strong_correlations:
        unique_strong_correlations[sorted_pair] = value

strongest_three = pd.Series(unique_strong_correlations).nlargest(3)

_strongest_three_correlations = strongest_three

# %% [markdown]
# ### Interpretation of Strongest Correlations
#
# Based on the correlation matrix, the three strongest correlations observed are:
#
# 1.  **T2M (Temperature at 2 Meters) and T2M_MAX (Maximum Temperature at 2 Meters):**
#     *   **Correlation:** 0.88
#     *   **Interpretation:** This is a very strong positive correlation, indicating that as the average daily temperature (T2M) increases, the daily maximum temperature (T2M_MAX) also tends to increase significantly. This is expected, as daily maximum temperature is a major component of the daily average temperature.
#
# 2.  **T2M (Temperature at 2 Meters) and T2M_MIN (Minimum Temperature at 2 Meters):**
#     *   **Correlation:** 0.52
#     *   **Interpretation:** A strong positive correlation suggests that higher average daily temperatures are associated with higher daily minimum temperatures. This also makes sense, as a warmer day typically has warmer nights.
#
# 3.  **T2M_MAX (Maximum Temperature at 2 Meters) and T2M_RANGE (Temperature Range at 2 Meters):**
#     *   **Correlation:** 0.81
#     *   **Interpretation:** This strong positive correlation indicates that when the maximum temperature is high, the daily temperature range also tends to be large. This could suggest days with clear skies, allowing for high daytime heating and significant nighttime cooling, or simply that very high maximum temperatures naturally lead to a larger range from the minimum temperature.

# %% [markdown]
# # Distribution Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Histogram of PRECTOTCORR
plt.figure(figsize=(10, 6))
sns.histplot(df['PRECTOTCORR'], kde=True, bins=50)
plt.title('Distribution of PRECTOTCORR')
plt.xlabel('Precipitation (mm)')
plt.ylabel('Frequency')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# Check for skewness
skewness_prectotcorr = df['PRECTOTCORR'].skew()
print(f"Skewness of PRECTOTCORR: {skewness_prectotcorr:.2f}")

# If heavily skewed (e.g., skewness > 1 or < -1), apply log transformation and plot again
if skewness_prectotcorr > 1 or skewness_prectotcorr < -1:
    # Add a small constant to avoid log(0) if there are zero values
    df['PRECTOTCORR_log'] = np.log1p(df['PRECTOTCORR'])
    plt.figure(figsize=(10, 6))
    sns.histplot(df['PRECTOTCORR_log'], kde=True, bins=50)
    plt.title('Distribution of Log-transformed PRECTOTCORR')
    plt.xlabel('Log(1+Precipitation)')
    plt.ylabel('Frequency')
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.show()
    print(f"Skewness of Log-transformed PRECTOTCORR: {df['PRECTOTCORR_log'].skew():.2f}")
# Out:
# Skewness of PRECTOTCORR: 5.51
# Skewness of Log-transformed PRECTOTCORR: 1.59

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(data=df, x='T2M', y='RH2M', size='PRECTOTCORR', sizes=(20, 1000), hue='PRECTOTCORR', legend='full', alpha=0.6)
plt.title('Bubble Chart: T2M vs. RH2M (Bubble Size = PRECTOTCORR)')
plt.xlabel('Temperature at 2 Meters (T2M)')
plt.ylabel('Relative Humidity at 2 Meters (RH2M)')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()
