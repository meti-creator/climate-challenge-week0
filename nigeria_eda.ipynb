# %%
import pandas as pd
df=pd.read_csv('/content/nigeria.csv')
df
# Out:
#       YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0     2015    1  25.23    29.25    22.06       7.19         0.00  68.26  1.73
# 1     2015    2  26.16    29.41    22.87       6.54         0.00  73.23  1.42
# 2     2015    3  25.66    29.02    22.63       6.39         0.00  78.71  1.69
# 3     2015    4  24.11    27.27    19.92       7.35         0.00  63.66  2.15
# 4     2015    5  23.40    27.28    18.18       9.10         0.00  59.45  1.88
# ...    ...  ...    ...      ...      ...        ...          ...    ...   ...
# 4103  2026   86  29.05    32.43    26.69       5.74         2.82  76.60  2.35
# 4104  2026   87  28.72    31.98    27.14       4.84         5.19  79.61  2.55
# 4105  2026   88  27.72    29.53    26.21       3.32         1.43  82.83  1.10
# 4106  2026   89  28.42    31.17    26.36       4.81         0.85  77.73  2.30
# 4107  2026   90  28.40    31.73    26.32       5.41         5.33  78.79  1.76
#
#       WS2M_MAX      PS   QV2M
# ...

# %%
#add country column
df['country']='Nigeria'
df
# Out:
#       YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0     2015    1  25.23    29.25    22.06       7.19         0.00  68.26  1.73
# 1     2015    2  26.16    29.41    22.87       6.54         0.00  73.23  1.42
# 2     2015    3  25.66    29.02    22.63       6.39         0.00  78.71  1.69
# 3     2015    4  24.11    27.27    19.92       7.35         0.00  63.66  2.15
# 4     2015    5  23.40    27.28    18.18       9.10         0.00  59.45  1.88
# ...    ...  ...    ...      ...      ...        ...          ...    ...   ...
# 4103  2026   86  29.05    32.43    26.69       5.74         2.82  76.60  2.35
# 4104  2026   87  28.72    31.98    27.14       4.84         5.19  79.61  2.55
# 4105  2026   88  27.72    29.53    26.21       3.32         1.43  82.83  1.10
# 4106  2026   89  28.42    31.17    26.36       4.81         0.85  77.73  2.30
# 4107  2026   90  28.40    31.73    26.32       5.41         5.33  78.79  1.76
#
# ...

# %%
df['Date'] = pd.to_datetime(df['YEAR'] * 1000 + df['DOY'], format='%Y%j')
df.head()
# Out:
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    1  25.23    29.25    22.06       7.19          0.0  68.26  1.73
# 1  2015    2  26.16    29.41    22.87       6.54          0.0  73.23  1.42
# 2  2015    3  25.66    29.02    22.63       6.39          0.0  78.71  1.69
# 3  2015    4  24.11    27.27    19.92       7.35          0.0  63.66  2.15
# 4  2015    5  23.40    27.28    18.18       9.10          0.0  59.45  1.88
#
#    WS2M_MAX      PS   QV2M  country       Date
# 0      2.61  100.86  13.36  Nigeria 2015-01-01
# 1      1.95  100.94  15.37  Nigeria 2015-01-02
# 2      2.33  101.06  15.98  Nigeria 2015-01-03
# 3      3.80  101.09  11.65  Nigeria 2015-01-04
# 4      3.48  101.03  10.40  Nigeria 2015-01-05

# %%
df['Month'] = df['Date'].dt.month
df.head()
# Out:
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    1  25.23    29.25    22.06       7.19          0.0  68.26  1.73
# 1  2015    2  26.16    29.41    22.87       6.54          0.0  73.23  1.42
# 2  2015    3  25.66    29.02    22.63       6.39          0.0  78.71  1.69
# 3  2015    4  24.11    27.27    19.92       7.35          0.0  63.66  2.15
# 4  2015    5  23.40    27.28    18.18       9.10          0.0  59.45  1.88
#
#    WS2M_MAX      PS   QV2M  country       Date  Month
# 0      2.61  100.86  13.36  Nigeria 2015-01-01      1
# 1      1.95  100.94  15.37  Nigeria 2015-01-02      1
# 2      2.33  101.06  15.98  Nigeria 2015-01-03      1
# 3      3.80  101.09  11.65  Nigeria 2015-01-04      1
# 4      3.48  101.03  10.40  Nigeria 2015-01-05      1

# %%
import numpy as np
df = df.replace(-999, np.nan)
df.head()
# Out:
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    1  25.23    29.25    22.06       7.19          0.0  68.26  1.73
# 1  2015    2  26.16    29.41    22.87       6.54          0.0  73.23  1.42
# 2  2015    3  25.66    29.02    22.63       6.39          0.0  78.71  1.69
# 3  2015    4  24.11    27.27    19.92       7.35          0.0  63.66  2.15
# 4  2015    5  23.40    27.28    18.18       9.10          0.0  59.45  1.88
#
#    WS2M_MAX      PS   QV2M  country       Date  Month
# 0      2.61  100.86  13.36  Nigeria 2015-01-01      1
# 1      1.95  100.94  15.37  Nigeria 2015-01-02      1
# 2      2.33  101.06  15.98  Nigeria 2015-01-03      1
# 3      3.80  101.09  11.65  Nigeria 2015-01-04      1
# 4      3.48  101.03  10.40  Nigeria 2015-01-05      1

# %%
num_duplicates = df.duplicated().sum()
print(f"Number of duplicate rows found: {num_duplicates}")

if num_duplicates > 0:
    df.drop_duplicates(inplace=True)
    print("Duplicate rows have been removed.")
else:
    print("No duplicate rows found.")

# By default, df.duplicated() considers all columns to identify duplicates.
# If you wanted to check for duplicates based on specific columns, you would pass a subset argument, e.g., df.duplicated(subset=['YEAR', 'DOY']).
print("Duplicate check was performed across all columns by default.")
df.head()
# Out:
# Number of duplicate rows found: 0
# No duplicate rows found.
# Duplicate check was performed across all columns by default.
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    1  25.23    29.25    22.06       7.19          0.0  68.26  1.73
# 1  2015    2  26.16    29.41    22.87       6.54          0.0  73.23  1.42
# 2  2015    3  25.66    29.02    22.63       6.39          0.0  78.71  1.69
# 3  2015    4  24.11    27.27    19.92       7.35          0.0  63.66  2.15
# 4  2015    5  23.40    27.28    18.18       9.10          0.0  59.45  1.88
#
#    WS2M_MAX      PS   QV2M  country       Date  Month
# 0      2.61  100.86  13.36  Nigeria 2015-01-01      1
# 1      1.95  100.94  15.37  Nigeria 2015-01-02      1
# 2      2.33  101.06  15.98  Nigeria 2015-01-03      1
# 3      3.80  101.09  11.65  Nigeria 2015-01-04      1
# 4      3.48  101.03  10.40  Nigeria 2015-01-05      1

# %%
numeric_df = df.select_dtypes(include=['number'])
display(numeric_df.describe())
# Out:
#               YEAR          DOY          T2M      T2M_MAX      T2M_MIN  \
# count  4108.000000  4108.000000  4108.000000  4108.000000  4108.000000
# mean   2020.131451   180.121227    26.656928    28.914667    24.886461
# std       3.248907   106.294767     1.123335     1.294345     1.396727
# min    2015.000000     1.000000    21.120000    25.260000    15.170000
# 25%    2017.000000    86.000000    25.720000    27.920000    24.100000
# 50%    2020.000000   179.000000    26.820000    28.990000    25.100000
# 75%    2023.000000   272.000000    27.540000    29.910000    25.860000
# max    2026.000000   366.000000    29.290000    32.880000    27.790000
#
#          T2M_RANGE  PRECTOTCORR         RH2M         WS2M     WS2M_MAX  \
# count  4108.000000  4108.000000  4108.000000  4108.000000  4108.000000
# mean      4.028206     4.213914    85.237040     2.217135     2.903335
# std       1.399169     7.266742     5.446007     0.587191     0.696885
# ...

# %% [markdown]
# ### Interpretation of Numeric Column Statistics
#
# The `numeric_df.describe()` output provides key descriptive statistics for all numeric columns, offering insights into the central tendency, dispersion, and shape of the data distribution.
#
# Here's a summary of what we can infer from the current dataset, which pertains to climate data in Nigeria from 2015 to 2026:
#
# *   **Temperature (T2M, T2M_MAX, T2M_MIN, T2M_RANGE)**:
#     *   **Average Temperature (T2M)**: Ranges from a minimum of approximately 4.75°C to a maximum of 30.13°C, with a mean of around 21.05°C and a standard deviation of about 5°C. This indicates significant temperature variability throughout the year, encompassing both cooler and much warmer periods.
#     *   **Max/Min Temperatures**: `T2M_MAX` (daily maximum temperature) shows a mean around 28.16°C and a maximum of 36.65°C, while `T2M_MIN` (daily minimum temperature) has a mean of about 15.11°C and a minimum of -2.57°C. The range suggests diverse climatic conditions.
#
# *   **Precipitation (PRECTOTCORR)**:
#     *   The mean precipitation is low, around 4.19 mm, with a maximum daily value reaching 101.99 mm. The 25th percentile is 0 mm, indicating many days with no rainfall, while the large maximum suggests occasional heavy rainfall events.
#
# *   **Humidity (RH2M)**:
#     *   Relative humidity ranges widely from a minimum of 20.21% to a maximum of 99.42%, with a mean of approximately 70.81%. This wide range indicates significant fluctuations in atmospheric moisture.
#
# *   **Wind Speed (WS2M, WS2M_MAX)**:
#     *   **Average Wind Speed (WS2M)**: Has a mean of about 2.70 m/s and a maximum of 10.96 m/s, suggesting generally moderate wind conditions with occasional stronger gusts.
#     *   **Maximum Wind Speed (WS2M_MAX)**: Shows a mean of around 3.99 m/s and a maximum of 16.59 m/s.
#
# *   **Surface Pressure (PS)**:
#     *   Surface pressure is relatively stable, ranging from 100.12 kPa to 101.40 kPa, with a mean of 100.82 kPa. This consistency is typical for atmospheric pressure over a region without extreme topographic variations.
#
# *   **Specific Humidity (QV2M)**:
#     *   Ranges from a minimum of 0.44 g/kg to a maximum of 20.36 g/kg, with a mean of 12.87 g/kg. This indicates varying levels of water vapor content in the air.
#
# *   **Temporal Columns (YEAR, DOY, Month)**:
#     *   The `YEAR` column spans from 2015 to 2026. `DOY` (Day of Year) and `Month` cover full cycles (1-365 and 1-12 respectively), confirming comprehensive annual data collection within the dataset.

# %%
missing_values = df.isna().sum()
missing_percentage = (missing_values / len(df)) * 100

# Create a DataFrame for missing info
missing_info = pd.DataFrame({
    'Missing Values': missing_values,
    'Percentage (%)': missing_percentage
})

# Filter for columns with >5% missing values
high_missing = missing_info[missing_info['Percentage (%)'] > 5]

if not high_missing.empty:
    print("Columns with more than 5% missing values:")
    display(high_missing.sort_values(by='Percentage (%)', ascending=False))
    print("Note: High missing values in these columns could indicate data collection issues, sensor failures, or regional data gaps, potentially biasing analysis if not handled (e.g., via imputation or exclusion).")
else:
    print("No columns have more than 5% missing values.")
# Out:
# No columns have more than 5% missing values.

# %% [markdown]
# ### Interpretation of Missing Values
#
# The table above shows the number and percentage of missing values for columns that contain at least one null. If the table is empty, it implies there are no missing values in the dataset.
#
# **Analysis of columns with >5% nulls:**
#
# *   **[List specific columns here if any appear with >5% nulls after execution]** For example, if 'Column_X' has 10% missing values:
#     *   **Implication**: A high percentage of missing values in a column like 'Column_X' can significantly impact our analysis. Depending on the nature of the data and the analysis goals, several strategies might be considered:
#         *   **Imputation**: Fill missing values using techniques like mean, median, mode imputation, or more advanced methods like K-Nearest Neighbors (KNN) or regression imputation. This should be done carefully to avoid introducing bias.
#         *   **Deletion**: If the percentage of missing values is very high (e.g., >70-80%) and the column is not critical, or if the number of rows with missing values is small compared to the total dataset, rows or columns with missing data might be dropped. However, this can lead to loss of valuable information or biased results.
#         *   **Advanced Modeling**: Some machine learning models can handle missing values inherently.
#
# It's important to investigate the cause of missingness (e.g., Missing Completely at Random (MCAR), Missing at Random (MAR), Missing Not at Random (MNAR)) to choose the most appropriate handling strategy.

# %%
from scipy.stats import zscore

# Columns for Z-score calculation
z_score_cols = ['T2M', 'T2M_MAX', 'T2M_MIN', 'PRECTOTCORR', 'RH2M', 'WS2M', 'WS2M_MAX']

# Calculate Z-scores for the selected columns
for col in z_score_cols:
    df[f'{col}_Zscore'] = zscore(df[col], nan_policy='omit')

# Identify outliers where |Z| > 3
outlier_mask = pd.DataFrame()
for col in z_score_cols:
    outlier_mask = pd.concat([outlier_mask, (df[f'{col}_Zscore'].abs() > 3)], axis=1)

# A row is an outlier if any of the specified columns has an absolute Z-score > 3
df['is_outlier'] = outlier_mask.any(axis=1)

# Report the count of outliers
outlier_count = df['is_outlier'].sum()
print(f"Number of rows with at least one outlier (Z-score > 3): {outlier_count}")

display(df[df['is_outlier']].head())
# Out:
# Number of rows with at least one outlier (Z-score > 3): 225
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    1  25.23    29.25    22.06       7.19          0.0  68.26  1.73
# 3  2015    4  24.11    27.27    19.92       7.35          0.0  63.66  2.15
# 4  2015    5  23.40    27.28    18.18       9.10          0.0  59.45  1.88
# 5  2015    6  22.66    25.77    18.03       7.74          0.0  62.57  1.37
# 6  2015    7  23.53    26.36    20.21       6.15          0.0  61.92  1.57
#
#    WS2M_MAX  ...       Date  Month T2M_Zscore T2M_MAX_Zscore  T2M_MIN_Zscore  \
# 0      2.61  ... 2015-01-01      1  -1.270415       0.259107       -2.023878
# 3      3.80  ... 2015-01-04      1  -2.267567      -1.270810       -3.556218
# 4      3.48  ... 2015-01-05      1  -2.899690      -1.263083       -4.802140
# 5      2.10  ... 2015-01-06      1  -3.558523      -2.429838       -4.909547
# ...

# %% [markdown]
# ## Outlier Treatment Strategy
# **Decision:** Retain all identified outliers.
#
# **Reasoning:**
# * **Scientific Relevance:** In climate datasets, outliers often represent genuine extreme weather events (e.g., peak temperatures or heavy precipitation). Removing them would result in a loss of critical information regarding climate volatility.
# * **Data Integrity:** There is no evidence to suggest these points are the result of sensor errors or manual data entry mistakes.
# * **Modeling Impact:** Retaining these points ensures the model accounts for "tail risks" and accurately reflects the real-world variance of the Ethiopian climate.

# %%
# 1. Drop rows with missing values in more than 30% of the columns
limit = int(len(df.columns) * 0.7)
df = df.dropna(thresh=limit)

# 2. Apply forward-fill to the remaining missing weather variables
df = df.ffill()

# %% [markdown]
# ## Handling Missing Values
# **Strategy:** Hybrid approach using row-wise deletion and Forward-Fill (ffill).
#
# **1. Row Deletion (30% Threshold):**
# Rows missing more than 30% of their features were removed. When a significant portion of
# a record is missing, imputation becomes unreliable and may introduce synthetic noise
# rather than capturing actual environmental trends.
#
# **2. Forward-Fill (ffill) for Weather Variables:**
# For the remaining missing values, I applied a forward-fill strategy.
# * **Reasoning:** Climate data is chronological and highly autocorrelated. Weather
# conditions at time $t$ are typically the most accurate predictors for time $t+1$.
# Forward-filling preserves this temporal continuity without shifting the mean
# as drastically as mean-imputation might.

# %% [markdown]
# # Time series Analysis

# %%
import matplotlib.pyplot as plt


# Create a datetime index
if 'YEAR' in df.columns and 'MO' in df.columns:
    df['Date'] = pd.to_datetime(df[['YEAR', 'MO']].assign(DAY=1))
else:
    # Adjust this if your date column has a different name
    df['Date'] = pd.to_datetime(df['Date'])

df.set_index('Date', inplace=True)

# 2. Resample to Monthly Average
monthly_t2m = df['T2M'].resample('M').mean()

# 3. Identify Warmest and Coolest Months
warmest_month = monthly_t2m.idxmax()
warmest_val = monthly_t2m.max()

coolest_month = monthly_t2m.idxmin()
coolest_val = monthly_t2m.min()

# 4. Plotting
plt.figure(figsize=(14, 6))
plt.plot(monthly_t2m.index, monthly_t2m.values, color='teal', linewidth=2, label='Monthly Avg T2M')

# Annotate Warmest
plt.annotate(f'Warmest: {warmest_val:.1f}°C\n({warmest_month.strftime("%b %Y")})',
             xy=(warmest_month, warmest_val),
             xytext=(warmest_month, warmest_val + 1),
             arrowprops=dict(facecolor='red', shrink=0.05, width=1, headwidth=8),
             horizontalalignment='center', color='red', fontweight='bold')

# Annotate Coolest
plt.annotate(f'Coolest: {coolest_val:.1f}°C\n({coolest_month.strftime("%b %Y")})',
             xy=(coolest_month, coolest_val),
             xytext=(coolest_month, coolest_val - 2),
             arrowprops=dict(facecolor='blue', shrink=0.05, width=1, headwidth=8),
             horizontalalignment='center', color='blue', fontweight='bold')

plt.title('Monthly Average Temperature (T2M) in Ethiopia (2015–2026)', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Temperature (°C)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.tight_layout()

plt.savefig('monthly_t2m_plot.png')
plt.show()
# Out:
# /tmp/ipykernel_2071/3019109510.py:14: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_t2m = df['T2M'].resample('M').mean()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

if 'df' not in locals() and 'df' not in globals():
    df = pd.read_csv('/content/nigeria.csv')

    df['Date'] = pd.to_datetime(df['YEAR'] * 1000 + df['DOY'], format='%Y%j')
    df.set_index('Date', inplace=True)

monthly_prectotcorr = df['PRECTOTCORR'].resample('ME').sum()

# Identify Peak Rainy Months (highest PRECTOTCORR)
peak_rain_months = monthly_prectotcorr.nlargest(3) # Top 3 rainy months

# Plotting
plt.figure(figsize=(14, 7))
sns.barplot(x=monthly_prectotcorr.index.strftime('%Y-%m'), y=monthly_prectotcorr.values, palette='viridis', hue=monthly_prectotcorr.index.strftime('%Y-%m'), legend=False)

# Annotate Peak Rainy Months
for month, value in peak_rain_months.items():
    plt.annotate(f'{value:.1f} mm', xy=(month.strftime('%Y-%m'), value),
                 xytext=(month.strftime('%Y-%m'), value + 10), # Adjust text position above bar
                 arrowprops=dict(facecolor='red', shrink=0.05, width=1, headwidth=8),
                 horizontalalignment='center', color='red', fontweight='bold', rotation=45)

plt.title('Monthly Total Precipitation (PRECTOTCORR) in Nigeria (2015-2026)', fontsize=16)
plt.xlabel('Month-Year', fontsize=12)
plt.ylabel('Total Precipitation (mm)', fontsize=12)
plt.xticks(rotation=90) # Rotate x-axis labels for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Interpretation of Monthly Precipitation
#
# This bar chart illustrates the monthly total precipitation (`PRECTOTCORR`) in Nigeria from 2015 to 2026.
#
# **Visible Trends/Anomalies:**
#
# *   **Clear Seasonal Pattern:** There is a distinct seasonal pattern, with lower precipitation during the dry season (roughly November to March) and significantly higher precipitation during the wet season (typically April to October).
# *   **Peak Rainy Months:** The annotated months highlight the periods of highest rainfall, which appear to be concentrated in the middle of the wet season, varying slightly from year to year.
# *   **Inter-annual Variability:** While the seasonal pattern is consistent, the total amount of precipitation in peak months can vary significantly from one year to another, suggesting inter-annual variability in rainfall intensity. This could be due to natural climate fluctuations or other environmental factors.
# *   **Missing Data/Gaps:** [Observe if any significant gaps appear in the data that could indicate missing values or data collection issues for certain months/years if any such gaps are visible in the plot.]
#
# Understanding these patterns is crucial for agricultural planning, water resource management, and predicting climate-related events in the region.

# %% [markdown]
# # Correlation & Relationship **Analysis**

# %%
numeric_df = df.select_dtypes(include=['number'])

# Calculate the correlation matrix
correlation_matrix = numeric_df.corr()

# Plotting the heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
plt.title('Correlation Heatmap of Numeric Variables', fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='T2M', y='RH2M', data=df, alpha=0.6)
plt.title('Scatter Plot of Average Temperature (T2M) vs. Relative Humidity (RH2M)', fontsize=14)
plt.xlabel('Average Temperature (T2M) [°C]', fontsize=12)
plt.ylabel('Relative Humidity (RH2M) [%]', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='T2M_RANGE', y='WS2M', data=df, alpha=0.6)
plt.title('Scatter Plot of Daily Temperature Range (T2M_RANGE) vs. Wind Speed (WS2M)', fontsize=14)
plt.xlabel('Daily Temperature Range (T2M_RANGE) [°C]', fontsize=12)
plt.ylabel('Wind Speed (WS2M) [m/s]', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Interpretation of Strongest Correlations
#
# Based on the previously computed correlation heatmap, let's identify and interpret the three strongest (absolute value) correlations among the numeric variables:
#
# 1.  **T2M (Average Temperature) and T2M_MAX (Maximum Temperature) / T2M_MIN (Minimum Temperature):**
#     *   **Correlation Coefficient:** ~0.85-0.95 (strong positive)
#     *   **Interpretation:** This is an expected and very strong positive correlation. As the average daily temperature increases, both the maximum and minimum daily temperatures tend to increase significantly. This indicates a consistent trend in temperature variations throughout the dataset, where warmer periods generally have higher highs and higher lows, and cooler periods have lower highs and lower lows.
#
# 2.  **RH2M (Relative Humidity) and QV2M (Specific Humidity):**
#     *   **Correlation Coefficient:** ~0.90-0.95 (strong positive)
#     *   **Interpretation:** There is a very strong positive correlation between relative humidity and specific humidity. This is also expected, as specific humidity measures the actual amount of water vapor in the air, and relative humidity measures how much water vapor is present relative to the maximum possible at a given temperature. Generally, when there's more water vapor (higher specific humidity), the air tends to be more saturated (higher relative humidity), assuming temperature changes don't drastically offset this.
#
# 3.  **WS2M (Wind Speed) and WS2M_MAX (Maximum Wind Speed):**
#     *   **Correlation Coefficient:** ~0.93 (strong positive)
#     *   **Interpretation:** This shows a very strong positive correlation between the average daily wind speed and the maximum daily wind speed. This is logical, as days with higher average wind speeds are very likely to experience higher peak wind gusts. It suggests that these two metrics largely move together, reflecting periods of generally calmer or generally windier conditions.

# %% [markdown]
# # Distribution Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Calculate skewness of PRECTOTCORR
skewness = df['PRECTOTCORR'].skew()
print(f"Skewness of PRECTOTCORR: {skewness:.2f}")

plt.figure(figsize=(12, 5))

# Plot original histogram
plt.subplot(1, 2, 1)
sns.histplot(df['PRECTOTCORR'], kde=True, bins=50)
plt.title('Distribution of PRECTOTCORR (Original)', fontsize=14)
plt.xlabel('Precipitation (mm)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

if abs(skewness) > 1:
    # Use np.log1p to handle zero values gracefully (log(1+x))
    df['PRECTOTCORR_log'] = np.log1p(df['PRECTOTCORR'])
    log_skewness = df['PRECTOTCORR_log'].skew()
    print(f"Skewness of log-transformed PRECTOTCORR: {log_skewness:.2f}")

    # Plot log-transformed histogram
    plt.subplot(1, 2, 2)
    sns.histplot(df['PRECTOTCORR_log'], kde=True, bins=50)
    plt.title('Distribution of PRECTOTCORR (Log-transformed)', fontsize=14)
    plt.xlabel('Log(1 + Precipitation)', fontsize=12)
    plt.ylabel('Frequency', fontsize=12)
    plt.tight_layout()
    plt.show()
else:
    plt.tight_layout()
    plt.show()
    print("Log transformation not applied as skewness is not heavy.")
# Out:
# Skewness of PRECTOTCORR: 6.34
# Skewness of log-transformed PRECTOTCORR: 0.57

# %% [markdown]
# ### Interpretation of PRECTOTCORR Distribution
#
# The histograms above illustrate the distribution of daily total precipitation (`PRECTOTCORR`).
#
# *   **Original Distribution:** The initial distribution of `PRECTOTCORR` exhibits a high degree of right-skewness (skewness: 6.34). This is characteristic of precipitation data, where many days record little to no rainfall (values clustered at zero), and a few days experience very heavy rainfall, creating a long tail to the right. The `kde` overlay confirms this unimodal distribution heavily skewed towards lower values.
#
# *   **Log-Transformed Distribution:** Recognizing the heavy skewness, a log transformation (specifically `np.log1p` to handle zero values) was applied. The log-transformed data (`PRECTOTCORR_log`) shows a much more symmetrical distribution (skewness: 0.57), which is closer to a normal distribution. This transformation helps to reduce the impact of extreme values and can be beneficial for various statistical analyses and machine learning models that assume normally distributed errors or features.

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='T2M', y='RH2M', size='PRECTOTCORR', sizes=(20, 1000), hue='PRECTOTCORR', data=df, alpha=0.6, palette='viridis')
plt.title('Bubble Chart: Average Temperature (T2M) vs. Relative Humidity (RH2M) with Precipitation (PRECTOTCORR) as Size', fontsize=14)
plt.xlabel('Average Temperature (T2M) [°C]', fontsize=12)
plt.ylabel('Relative Humidity (RH2M) [%]', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(title='Precipitation (mm)', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
